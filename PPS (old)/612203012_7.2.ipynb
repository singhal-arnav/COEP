# %%
def area(radius, pi=3.14):
  a = pi * radius**2
  return a

r1 = float(input('Enter the radius of the first circle: '))
r2 = float(input('Enter the radius of the second circle: '))
r3 = float(input('Enter the radius of the third circle: '))

print('Area of the first circle =', area(r1, 3.14159))
print('Area of the second circle =', area(pi = 22/7, radius = r2))
print('Area of the third circle =', area(r3))
# Out:
# Enter the radius of the first circle: 10
# Enter the radius of the second circle: 20
# Enter the radius of the third circle: 30
# Area of the first circle = 314.159
# Area of the second circle = 1257.142857142857
# Area of the third circle = 2826.0
