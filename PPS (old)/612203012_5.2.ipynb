# %%
amt = 0
print('Enter the price of the 5 chocolates:')

for i in range(5):
  price = int(input(str(i+1) + ': '))
  amt += price

print('Total amount = Rs.', amt*7)
# Out:
# Enter the price of the 5 chocolates:
# 1: 5
# 2: 10
# 3: 20
# 4: 50
# 5: 25
# Total amount = Rs. 770
