# %%
n = int(input('Enter the limit:'))
x = int(input('Enter the value of x:'))
sum = 0

for i in range(1, n+1):
  fact = 1
  for j in range(1, i+1):
    fact *= j
  sum += (x**i)/fact

print('Sum of the series =', sum)
# Out:
# Enter the limit:5
# Enter the value of x:7
# Sum of the series = 328.76666666666665
