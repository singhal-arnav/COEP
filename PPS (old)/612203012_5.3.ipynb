# %%
password = 'd23ald%2@#(ls.'

for i in range(3):
  pwd = input('Enter the password:')
  if pwd == password:
    print('Welcome')
    break
  elif i < 2:
    print('Incorrect password. Try again. Number of attempts left:', (2-i))
  else:
    print('3 attempts over.')
# Out:
# Enter the password:d23
# Incorrect password. Try again. Number of attempts left: 2
# Enter the password:ald%2
# Incorrect password. Try again. Number of attempts left: 1
# Enter the password:d23ald%2@#(ls.
# Welcome
