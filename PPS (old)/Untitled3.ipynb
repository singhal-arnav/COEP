# %%
n = int(input('Enter a number:'))

lsd = 0
while n!=0:
  if n%10 == 0:
    n/=10
  else:
    lsd = n%10
    break

if lsd == 5:
  print('Square of the number =', n**2)
else:
  print('Least significant digit is not 5')
# Out:
# Enter a number:10025
# Square of the number = 100500625
