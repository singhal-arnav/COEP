# %%
l = [23, 35, 12, 82, 3, 90, 4, 45]
max = min = l[0]
for i in range(1, len(l)):
  if l[i] > max:
    sec_max = max
    max = l[i]
  if l[i] < min:
    min = l[i]
print('Minimum element =', min)
print('Maximum element =', max)
print('Second maximum element =', sec_max)
# Out:
# Minimum element = 3
# Maximum element = 90
# Second maximum element = 82
