# %%
age = int(input('Enter the age of the student:'))
if age < 20 and age > 17:
  print('Student is eligible to join the college cricket club')
else:
  print('Student is not eligible to join the college cricket club')
# Out:
# Enter the age of the student:18
# Student is eligible to join the college cricket club
